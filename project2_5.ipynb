# %% [markdown]
# combine data

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from sklearn.ensemble import RandomForestRegressor
from math import sqrt
from flaml import AutoML

xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
file_names = ['003_2006_2080_352_360.nc','004_2006_2080_352_360.nc','005_2006_2080_352_360.nc',
              '006_2006_2080_352_360.nc','007_2006_2080_352_360.nc','008_2006_2080_352_360.nc']
datasets = [xr.open_dataset(f).expand_dims("source").assign_coords(source=[f]) for f in file_names]
combined_dataset = xr.concat(datasets, dim="source")
combined_dataset
# Out:
# C:\Users\HP\anaconda3\envs\myenv\Lib\site-packages\ecmwflibs\__init__.py:81: UserWarning: DLL load failed while importing _ecmwflibs: 找不到指定的程序。
#   warnings.warn(str(e))
# C:\Users\HP\anaconda3\envs\myenv\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# <xarray.Dataset> Size: 390MB
# Dimensions:     (source: 6, time: 27374, lat: 11, lon: 6)
# Coordinates:
#   * lat         (lat) float32 44B 49.48 50.42 51.36 52.3 ... 57.02 57.96 58.9
#   * lon         (lon) float32 24B 352.5 353.8 355.0 356.2 357.5 358.8
#   * time        (time) object 219kB 2006-01-02 00:00:00 ... 2080-12-31 00:00:00
#   * source      (source) <U24 576B '003_2006_2080_352_360.nc' ... '008_2006_2...
# Data variables:
#     TREFMXAV_U  (source, time, lat, lon) float32 43MB nan nan nan ... nan nan
#     FLNS        (source, time, lat, lon) float32 43MB 76.48 78.5 ... 85.82 75.48
#     FSNS        (source, time, lat, lon) float32 43MB 44.47 47.31 ... 10.29 9.14
#     PRECT       (source, time, lat, lon) float32 43MB 1.158e-08 ... 6.275e-08
#     PRSN        (source, time, lat, lon) float32 43MB 0.0 5.754e-23 ... 1.98e-13
#     QBOT        (source, time, lat, lon) float32 43MB 0.005241 ... 0.004433
#     TREFHT      (source, time, lat, lon) float32 43MB 284.4 284.2 ... 280.9
#     UBOT        (source, time, lat, lon) float32 43MB 7.604 6.998 ... 6.827 7.6
#     VBOT        (source, time, lat, lon) float32 43MB -3.69 -4.547 ... 5.44

# %%
combined_dataset.to_netcdf('combined_dataset.nc')

# %% [markdown]
# Data preprocessing and only Manchester

# %%
man_lat = 53.246075
man_lon = 357.5
ds = combined_dataset.sel(lat = man_lat, lon = man_lon, method = 'nearest')
#turn to dataframe
df = ds.to_dataframe().reset_index()

# %%
df = df.drop(['lat', 'lon'], axis=1)

# %%
#deal with time information
df['time'] = df['time'].astype(str)
df['time'] = pd.to_datetime(df['time'])
#Split time to year, month, day of year
df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month
df['dayofyear'] = df['time'].dt.dayofyear

#change source name
df['source'] = df['source'].str.split('_').str[0]
df['source'] = df['source'].astype(int)

# %%
df
# Out:
#         source       time  TREFMXAV_U       FLNS       FSNS         PRECT  \
# 0            3 2006-01-02  282.775848  41.925179  25.926952  4.663135e-09
# 1            3 2006-01-03  284.471130   8.905806  10.946910  8.046593e-08
# 2            3 2006-01-04  284.287964  16.511415   6.405902  2.910935e-09
# 3            3 2006-01-05  282.121094  29.948362   9.315041  7.432505e-11
# 4            3 2006-01-06  280.890900  19.064156   7.941241  6.894238e-12
# ...        ...        ...         ...        ...        ...           ...
# 164239       8 2080-12-27  286.378754  17.438847   6.720299  3.892051e-08
# 164240       8 2080-12-28  286.621307  26.986507  12.976557  2.301632e-07
# 164241       8 2080-12-29  282.327393  41.652626  16.614481  2.653475e-08
# 164242       8 2080-12-30  281.410248  56.226501  24.193817  1.709695e-08
# 164243       8 2080-12-31  280.582733  46.781525  24.450218  1.749981e-08
#
#                 PRSN      QBOT      TREFHT      UBOT      VBOT  year  month  \
# 0       4.781004e-17  0.004769  279.142883  3.878579  1.394184  2006      1
# 1       1.295726e-16  0.006271  281.148651  1.788157  3.821703  2006      1
# 2       4.094447e-16  0.005782  281.223785  0.804845 -2.299140  2006      1
# 3       0.000000e+00  0.004277  278.397675 -1.100267 -1.258029  2006      1
# 4       0.000000e+00  0.003990  278.063782 -0.706321 -0.938421  2006      1
# ...              ...       ...         ...       ...       ...   ...    ...
# 164239  7.616115e-15  0.006004  282.548523  2.741483  7.565282  2080     12
# 164240  6.722780e-16  0.005813  281.885712  4.295599  7.222901  2080     12
# 164241  1.264485e-15  0.004281  279.076965  3.328679  4.574871  2080     12
# 164242  2.954024e-17  0.004289  277.916626  2.779102  4.442761  2080     12
# 164243  1.094167e-12  0.004278  277.412048 -0.026990  3.524161  2080     12
#
#         dayofyear
# 0               2
# 1               3
# 2               4
# 3               5
# 4               6
# ...           ...
# 164239        362
# 164240        363
# 164241        364
# 164242        365
# 164243        366
#
# [164244 rows x 14 columns]

# %%
correlation_matrix = df.drop(['source','time'], axis=1).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Variables')
plt.show()

# %%
min_max_scaler = MinMaxScaler()
df['TREFMXAV_U_scaled'] = min_max_scaler.fit_transform(df[['TREFMXAV_U']])

# %%
#split train and test
train = df[df['time'].dt.year < 2050]
test = df[df['time'].dt.year >= 2050]

# %%
test_3 = test[test['source'] == 3]
test_4 = test[test['source'] == 4]
test_5 = test[test['source'] == 5]
test_6 = test[test['source'] == 6]
test_7 = test[test['source'] == 7]
test_8 = test[test['source'] == 8]

# %%
#train and X_test
X_train = train.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 
y_train = train['TREFMXAV_U_scaled']
X_test = test.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1) 
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred_scaled = model.predict(X_test_scaled)
test['predict_scaled'] = y_pred_scaled
y_pred_scaled = y_pred_scaled.reshape(-1, 1)
y_pred = min_max_scaler.inverse_transform(y_pred_scaled)
y_pred = y_pred.flatten()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\911604702.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict_scaled'] = y_pred_scaled

# %%
test['predict'] = y_pred
test_mean = test.groupby('time').mean().reset_index()
test_mean = test_mean.drop(['source'], axis=1)
test_mean
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\954511348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict'] = y_pred
#             time  TREFMXAV_U       FLNS       FSNS         PRECT  \
# 0     2050-01-01  285.341278  29.458427  12.151672  7.680542e-08
# 1     2050-01-02  285.206696  30.211699  13.940259  1.075110e-07
# 2     2050-01-03  284.320740  37.802864  16.033865  8.329342e-08
# 3     2050-01-04  282.648041  44.336731  20.012060  5.740878e-08
# 4     2050-01-05  282.077789  48.498402  25.349710  1.484214e-08
# ...          ...         ...        ...        ...           ...
# 11310 2080-12-27  284.036407  40.512272  20.476927  5.581414e-08
# 11311 2080-12-28  285.124451  32.158920  16.042503  6.051836e-08
# 11312 2080-12-29  284.690643  37.020874  15.653885  1.658894e-08
# 11313 2080-12-30  282.814789  40.770557  18.284941  3.031338e-08
# 11314 2080-12-31  283.082489  28.274282  16.083336  3.383295e-08
#
#                PRSN      QBOT      TREFHT      UBOT      VBOT    year  month  \
# 0      1.036520e-15  0.005653  282.000793  4.784846  5.674775  2050.0    1.0
# 1      7.055950e-15  0.005635  280.954559  2.585883  4.609480  2050.0    1.0
# 2      2.721277e-15  0.004869  279.674713  2.405048  4.562534  2050.0    1.0
# 3      3.395890e-16  0.004550  278.381256  3.669507  2.940760  2050.0    1.0
# 4      3.921966e-15  0.004473  278.207855  3.288960  2.177729  2050.0    1.0
# ...             ...       ...         ...       ...       ...     ...    ...
# 11310  1.281563e-15  0.005026  279.936584  3.037782  1.580195  2080.0   12.0
# 11311  1.442036e-16  0.005688  280.993378  4.157229  4.039726  2080.0   12.0
# 11312  2.715376e-16  0.005063  280.913849  4.795880  3.623227  2080.0   12.0
# 11313  2.530820e-15  0.004991  279.478363  2.251704  2.931198  2080.0   12.0
# 11314  1.893652e-13  0.005235  280.001465  1.296047  3.204826  2080.0   12.0
#
#        dayofyear  TREFMXAV_U_scaled  predict_scaled     predict
# 0            1.0           0.350968        0.351079  285.345720
# 1            2.0           0.347598        0.337216  284.792183
# 2            3.0           0.325410        0.317613  284.009413
# 3            4.0           0.283519        0.278609  282.451980
# 4            5.0           0.269239        0.276067  282.350458
# ...          ...                ...             ...         ...
# 11310      362.0           0.318289        0.313486  283.844626
# 11311      363.0           0.345538        0.340097  284.907186
# 11312      364.0           0.334673        0.326543  284.366005
# 11313      365.0           0.287695        0.301473  283.364930
# 11314      366.0           0.294399        0.307896  283.621417
#
# [11315 rows x 16 columns]

# %%
y_test_mean = test_mean['TREFMXAV_U_scaled']
y_test_pred = test_mean['predict_scaled']

# %%
mse = mean_squared_error(y_test_mean, y_test_pred)
mae = mean_absolute_error(y_test_mean, y_test_pred)
r2 = r2_score(y_test_mean, y_test_pred)
rmse = sqrt(mse)

print(f'Validation Mean Squared Error (MSE): {mse}')
print(f'Validation Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Validation R-squared: {r2}')
# Out:
# Validation Mean Squared Error (MSE): 5.116665386557662e-05
# Validation Mean Absolute Error (MAE): 0.005625964092302259
# Root Mean Squared Error (RMSE): 0.007153087016496907
# Validation R-squared: 0.9965161793689357

# %% [markdown]
# AutoML

# %% [markdown]
# All model

# %%
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 50,  # in seconds
    "metric": "r2",
    "task": "regression"
}
automl.fit(X_train=X_train_scaled, y_train=y_train, **automl_settings)
# Out:
# [flaml.automl.logger: 04-25 05:21:24] {1680} INFO - task = regression
# [flaml.automl.logger: 04-25 05:21:24] {1691} INFO - Evaluation method: holdout
# [flaml.automl.logger: 04-25 05:21:24] {1789} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 04-25 05:21:24] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2345} INFO - Estimated sufficient time budget=1384s. Estimated necessary time budget=10s.
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.5116,	best estimator lgbm's best error=0.5116
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.5116,	best estimator lgbm's best error=0.5116
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.1803,	best estimator lgbm's best error=0.1803
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.2s,	estimator xgboost's best error=0.5116,	best estimator lgbm's best error=0.1803
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 4, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.2s,	estimator extra_tree's best error=0.1950,	best estimator lgbm's best error=0.1803
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 5, current learner rf
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.3s,	estimator rf's best error=0.1477,	best estimator rf's best error=0.1477
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.3s,	estimator lgbm's best error=0.0392,	best estimator lgbm's best error=0.0392
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.3s,	estimator lgbm's best error=0.0392,	best estimator lgbm's best error=0.0392
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.0302,	best estimator lgbm's best error=0.0302
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.0302,	best estimator lgbm's best error=0.0302
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.0302,	best estimator lgbm's best error=0.0302
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.0279,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.6s,	estimator rf's best error=0.0442,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.6s,	estimator xgboost's best error=0.5116,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.7s,	estimator rf's best error=0.0442,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.7s,	estimator xgboost's best error=0.1887,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.7s,	estimator lgbm's best error=0.0279,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:24] {2392} INFO -  at 0.8s,	estimator extra_tree's best error=0.0703,	best estimator lgbm's best error=0.0279
# [flaml.automl.logger: 04-25 05:21:24] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 0.9s,	estimator lgbm's best error=0.0189,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 0.9s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.0s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.0s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.3s,	estimator rf's best error=0.0286,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.5s,	estimator rf's best error=0.0230,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.6s,	estimator extra_tree's best error=0.0703,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:25] {2392} INFO -  at 1.7s,	estimator extra_tree's best error=0.0361,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:25] {2219} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 1.9s,	estimator rf's best error=0.0230,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.1s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.1s,	estimator extra_tree's best error=0.0269,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.2s,	estimator extra_tree's best error=0.0269,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.5s,	estimator lgbm's best error=0.0189,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.6s,	estimator lgbm's best error=0.0189,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:26] {2392} INFO -  at 2.7s,	estimator lgbm's best error=0.0189,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:26] {2219} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 2.8s,	estimator extra_tree's best error=0.0236,	best estimator lgbm's best error=0.0189
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.0s,	estimator lgbm's best error=0.0187,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.0s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.1s,	estimator extra_tree's best error=0.0236,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.2s,	estimator xgboost's best error=0.0766,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.3s,	estimator xgboost's best error=0.0377,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.5s,	estimator rf's best error=0.0224,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:27] {2392} INFO -  at 3.7s,	estimator xgboost's best error=0.0377,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:27] {2219} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:28] {2392} INFO -  at 3.8s,	estimator extra_tree's best error=0.0211,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:28] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:28] {2392} INFO -  at 4.4s,	estimator lgbm's best error=0.0187,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:28] {2219} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:28] {2392} INFO -  at 4.5s,	estimator extra_tree's best error=0.0211,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:28] {2219} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:28] {2392} INFO -  at 4.6s,	estimator extra_tree's best error=0.0211,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:28] {2219} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:28] {2392} INFO -  at 4.7s,	estimator xgboost's best error=0.0377,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:28] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:29] {2392} INFO -  at 4.9s,	estimator lgbm's best error=0.0187,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:29] {2219} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:29] {2392} INFO -  at 5.0s,	estimator extra_tree's best error=0.0211,	best estimator lgbm's best error=0.0187
# [flaml.automl.logger: 04-25 05:21:29] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:29] {2392} INFO -  at 5.4s,	estimator lgbm's best error=0.0162,	best estimator lgbm's best error=0.0162
# [flaml.automl.logger: 04-25 05:21:29] {2219} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:29] {2392} INFO -  at 5.4s,	estimator xgboost's best error=0.0377,	best estimator lgbm's best error=0.0162
# [flaml.automl.logger: 04-25 05:21:29] {2219} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:29] {2392} INFO -  at 5.5s,	estimator extra_tree's best error=0.0211,	best estimator lgbm's best error=0.0162
# [flaml.automl.logger: 04-25 05:21:29] {2219} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:30] {2392} INFO -  at 6.4s,	estimator lgbm's best error=0.0162,	best estimator lgbm's best error=0.0162
# [flaml.automl.logger: 04-25 05:21:30] {2219} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:31] {2392} INFO -  at 6.8s,	estimator lgbm's best error=0.0162,	best estimator lgbm's best error=0.0162
# [flaml.automl.logger: 04-25 05:21:31] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:31] {2392} INFO -  at 7.2s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:31] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.1s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.1s,	estimator xgboost's best error=0.0317,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.5s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 57, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.5s,	estimator xgb_limitdepth's best error=0.0225,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 58, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.6s,	estimator xgb_limitdepth's best error=0.0225,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 59, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:32] {2392} INFO -  at 8.6s,	estimator xgb_limitdepth's best error=0.0225,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:32] {2219} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 8.8s,	estimator rf's best error=0.0224,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 61, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 8.9s,	estimator xgb_limitdepth's best error=0.0225,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 62, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 9.2s,	estimator extra_tree's best error=0.0198,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 63, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 9.3s,	estimator xgb_limitdepth's best error=0.0209,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 9.4s,	estimator xgb_limitdepth's best error=0.0209,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 9.6s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:33] {2392} INFO -  at 9.7s,	estimator xgboost's best error=0.0238,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:33] {2219} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 9.8s,	estimator xgboost's best error=0.0238,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 9.9s,	estimator xgboost's best error=0.0238,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 10.2s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 70, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 10.3s,	estimator xgboost's best error=0.0238,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 10.5s,	estimator xgboost's best error=0.0234,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 10.6s,	estimator extra_tree's best error=0.0198,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 73, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:34] {2392} INFO -  at 10.7s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:34] {2219} INFO - iteration 74, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:35] {2392} INFO -  at 10.9s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:35] {2219} INFO - iteration 75, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:35] {2392} INFO -  at 11.0s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:35] {2219} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:35] {2392} INFO -  at 11.5s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:35] {2219} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 04-25 05:21:36] {2392} INFO -  at 12.6s,	estimator lgbm's best error=0.0161,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:36] {2219} INFO - iteration 78, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:37] {2392} INFO -  at 12.8s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:37] {2219} INFO - iteration 79, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:37] {2392} INFO -  at 12.9s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:37] {2219} INFO - iteration 80, current learner rf
# [flaml.automl.logger: 04-25 05:21:37] {2392} INFO -  at 13.3s,	estimator rf's best error=0.0202,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:37] {2219} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:37] {2392} INFO -  at 13.5s,	estimator xgb_limitdepth's best error=0.0176,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:37] {2219} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:37] {2392} INFO -  at 13.6s,	estimator xgboost's best error=0.0234,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:37] {2219} INFO - iteration 83, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:38] {2392} INFO -  at 13.8s,	estimator xgb_limitdepth's best error=0.0163,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:38] {2219} INFO - iteration 84, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:38] {2392} INFO -  at 14.0s,	estimator xgb_limitdepth's best error=0.0163,	best estimator lgbm's best error=0.0161
# [flaml.automl.logger: 04-25 05:21:38] {2219} INFO - iteration 85, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:38] {2392} INFO -  at 14.3s,	estimator xgb_limitdepth's best error=0.0156,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:38] {2219} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:38] {2392} INFO -  at 14.6s,	estimator xgb_limitdepth's best error=0.0156,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:38] {2219} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:39] {2392} INFO -  at 15.6s,	estimator xgb_limitdepth's best error=0.0156,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:39] {2219} INFO - iteration 88, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:40] {2392} INFO -  at 16.0s,	estimator extra_tree's best error=0.0194,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:40] {2219} INFO - iteration 89, current learner rf
# [flaml.automl.logger: 04-25 05:21:40] {2392} INFO -  at 16.3s,	estimator rf's best error=0.0202,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:40] {2219} INFO - iteration 90, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:40] {2392} INFO -  at 16.5s,	estimator xgb_limitdepth's best error=0.0156,	best estimator xgb_limitdepth's best error=0.0156
# [flaml.automl.logger: 04-25 05:21:40] {2219} INFO - iteration 91, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:42] {2392} INFO -  at 18.0s,	estimator xgb_limitdepth's best error=0.0152,	best estimator xgb_limitdepth's best error=0.0152
# [flaml.automl.logger: 04-25 05:21:42] {2219} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:42] {2392} INFO -  at 18.4s,	estimator xgb_limitdepth's best error=0.0152,	best estimator xgb_limitdepth's best error=0.0152
# [flaml.automl.logger: 04-25 05:21:42] {2219} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:49] {2392} INFO -  at 25.4s,	estimator xgb_limitdepth's best error=0.0151,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:49] {2219} INFO - iteration 94, current learner extra_tree
# [flaml.automl.logger: 04-25 05:21:49] {2392} INFO -  at 25.7s,	estimator extra_tree's best error=0.0194,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:49] {2219} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 04-25 05:21:50] {2392} INFO -  at 26.0s,	estimator rf's best error=0.0202,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:50] {2219} INFO - iteration 96, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:21:55] {2392} INFO -  at 30.9s,	estimator xgb_limitdepth's best error=0.0151,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:55] {2219} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:56] {2392} INFO -  at 32.1s,	estimator xgboost's best error=0.0172,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:56] {2219} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 04-25 05:21:56] {2392} INFO -  at 32.6s,	estimator xgboost's best error=0.0172,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:21:56] {2219} INFO - iteration 99, current learner xgboost
# [flaml.automl.logger: 04-25 05:22:00] {2392} INFO -  at 36.0s,	estimator xgboost's best error=0.0172,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:22:00] {2219} INFO - iteration 100, current learner rf
# [flaml.automl.logger: 04-25 05:22:00] {2392} INFO -  at 36.2s,	estimator rf's best error=0.0202,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:22:00] {2219} INFO - iteration 101, current learner xgb_limitdepth
# [flaml.automl.logger: 04-25 05:22:11] {2392} INFO -  at 47.4s,	estimator xgb_limitdepth's best error=0.0151,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:22:11] {2219} INFO - iteration 102, current learner xgboost
# [flaml.automl.logger: 04-25 05:22:15] {2392} INFO -  at 51.5s,	estimator xgboost's best error=0.0172,	best estimator xgb_limitdepth's best error=0.0151
# [flaml.automl.logger: 04-25 05:22:23] {2628} INFO - retrain xgb_limitdepth for 7.4s
# [flaml.automl.logger: 04-25 05:22:23] {2631} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.5493443205226077, colsample_bynode=None,
#              colsample_bytree=0.7643111740873823, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.024046005530042384, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=9.675016683297736, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=893,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 04-25 05:22:23] {1931} INFO - fit succeeded
# [flaml.automl.logger: 04-25 05:22:23] {1932} INFO - Time taken to find the best model: 25.425894260406494

# %%
print("best model:")
print(automl.model.estimator)
# Out:
# best model:
# XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.5493443205226077, colsample_bynode=None,
#              colsample_bytree=0.7643111740873823, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.024046005530042384, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=9.675016683297736, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=893,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_scaled = automl.predict(X_test_scaled)
test['predict_scaled'] = y_pred_scaled
y_pred_scaled = y_pred_scaled.reshape(-1, 1)
y_pred = min_max_scaler.inverse_transform(y_pred_scaled)
y_pred = y_pred.flatten()

test['predict'] = y_pred
test_mean = test.groupby('time').mean().reset_index()
test_mean = test_mean.drop(['source'], axis=1)

y_test_mean = test_mean['TREFMXAV_U_scaled']
y_test_pred = test_mean['predict_scaled']

mse = mean_squared_error(y_test_mean, y_test_pred)
mae = mean_absolute_error(y_test_mean, y_test_pred)
r2 = r2_score(y_test_mean, y_test_pred)
rmse = sqrt(mse)

print(f'AutoML Mean Squared Error (MSE): {mse}')
print(f'AutoML Mean Absolute Error (MAE): {mae}')
print(f'AutoML Root Mean Squared Error (RMSE): {rmse}')
print(f'AutoML R-squared: {r2}')
# Out:
# AutoML Mean Squared Error (MSE): 4.974872717866674e-05
# AutoML Mean Absolute Error (MAE): 0.005452340003103018
# AutoML Root Mean Squared Error (RMSE): 0.007053277761343781
# AutoML R-squared: 0.9966127227715909
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\571395812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict_scaled'] = y_pred_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\571395812.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict'] = y_pred

# %% [markdown]
# Only RF

# %%
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 50,  # in seconds
    "metric": "r2",
    "task": "regression",
    "estimator_list": ["rf"]
}

automl.fit(X_train=X_train_scaled, y_train=y_train, **automl_settings)
# Out:
# [flaml.automl.logger: 04-25 05:28:57] {1680} INFO - task = regression
# [flaml.automl.logger: 04-25 05:28:57] {1691} INFO - Evaluation method: holdout
# [flaml.automl.logger: 04-25 05:28:57] {1789} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 04-25 05:28:57] {1901} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl.logger: 04-25 05:28:57] {2219} INFO - iteration 0, current learner rf
# [flaml.automl.logger: 04-25 05:28:57] {2345} INFO - Estimated sufficient time budget=8895s. Estimated necessary time budget=9s.
# [flaml.automl.logger: 04-25 05:28:57] {2392} INFO -  at 0.1s,	estimator rf's best error=0.1477,	best estimator rf's best error=0.1477
# [flaml.automl.logger: 04-25 05:28:57] {2219} INFO - iteration 1, current learner rf
# [flaml.automl.logger: 04-25 05:28:57] {2392} INFO -  at 0.3s,	estimator rf's best error=0.0442,	best estimator rf's best error=0.0442
# [flaml.automl.logger: 04-25 05:28:57] {2219} INFO - iteration 2, current learner rf
# [flaml.automl.logger: 04-25 05:28:57] {2392} INFO -  at 0.4s,	estimator rf's best error=0.0442,	best estimator rf's best error=0.0442
# [flaml.automl.logger: 04-25 05:28:57] {2219} INFO - iteration 3, current learner rf
# [flaml.automl.logger: 04-25 05:28:58] {2392} INFO -  at 0.6s,	estimator rf's best error=0.0286,	best estimator rf's best error=0.0286
# [flaml.automl.logger: 04-25 05:28:58] {2219} INFO - iteration 4, current learner rf
# [flaml.automl.logger: 04-25 05:28:58] {2392} INFO -  at 0.8s,	estimator rf's best error=0.0230,	best estimator rf's best error=0.0230
# [flaml.automl.logger: 04-25 05:28:58] {2219} INFO - iteration 5, current learner rf
# [flaml.automl.logger: 04-25 05:28:58] {2392} INFO -  at 1.1s,	estimator rf's best error=0.0230,	best estimator rf's best error=0.0230
# [flaml.automl.logger: 04-25 05:28:58] {2219} INFO - iteration 6, current learner rf
# [flaml.automl.logger: 04-25 05:28:58] {2392} INFO -  at 1.3s,	estimator rf's best error=0.0224,	best estimator rf's best error=0.0224
# [flaml.automl.logger: 04-25 05:28:58] {2219} INFO - iteration 7, current learner rf
# [flaml.automl.logger: 04-25 05:28:59] {2392} INFO -  at 1.6s,	estimator rf's best error=0.0224,	best estimator rf's best error=0.0224
# [flaml.automl.logger: 04-25 05:28:59] {2219} INFO - iteration 8, current learner rf
# [flaml.automl.logger: 04-25 05:28:59] {2392} INFO -  at 2.0s,	estimator rf's best error=0.0202,	best estimator rf's best error=0.0202
# [flaml.automl.logger: 04-25 05:28:59] {2219} INFO - iteration 9, current learner rf
# [flaml.automl.logger: 04-25 05:28:59] {2392} INFO -  at 2.3s,	estimator rf's best error=0.0202,	best estimator rf's best error=0.0202
# [flaml.automl.logger: 04-25 05:28:59] {2219} INFO - iteration 10, current learner rf
# [flaml.automl.logger: 04-25 05:29:00] {2392} INFO -  at 2.8s,	estimator rf's best error=0.0202,	best estimator rf's best error=0.0202
# [flaml.automl.logger: 04-25 05:29:00] {2219} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 04-25 05:29:00] {2392} INFO -  at 3.3s,	estimator rf's best error=0.0200,	best estimator rf's best error=0.0200
# [flaml.automl.logger: 04-25 05:29:00] {2219} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 04-25 05:29:01] {2392} INFO -  at 3.6s,	estimator rf's best error=0.0200,	best estimator rf's best error=0.0200
# [flaml.automl.logger: 04-25 05:29:01] {2219} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 04-25 05:29:02] {2392} INFO -  at 4.6s,	estimator rf's best error=0.0192,	best estimator rf's best error=0.0192
# [flaml.automl.logger: 04-25 05:29:02] {2219} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 04-25 05:29:02] {2392} INFO -  at 5.1s,	estimator rf's best error=0.0192,	best estimator rf's best error=0.0192
# [flaml.automl.logger: 04-25 05:29:02] {2219} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 04-25 05:29:04] {2392} INFO -  at 6.7s,	estimator rf's best error=0.0190,	best estimator rf's best error=0.0190
# [flaml.automl.logger: 04-25 05:29:04] {2219} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 04-25 05:29:05] {2392} INFO -  at 7.5s,	estimator rf's best error=0.0190,	best estimator rf's best error=0.0190
# [flaml.automl.logger: 04-25 05:29:05] {2219} INFO - iteration 17, current learner rf
# [flaml.automl.logger: 04-25 05:29:05] {2392} INFO -  at 8.0s,	estimator rf's best error=0.0190,	best estimator rf's best error=0.0190
# [flaml.automl.logger: 04-25 05:29:05] {2219} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 04-25 05:29:08] {2392} INFO -  at 10.8s,	estimator rf's best error=0.0189,	best estimator rf's best error=0.0189
# [flaml.automl.logger: 04-25 05:29:08] {2219} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 04-25 05:29:13] {2392} INFO -  at 16.0s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:13] {2219} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 04-25 05:29:15] {2392} INFO -  at 18.3s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:15] {2219} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 04-25 05:29:18] {2392} INFO -  at 20.7s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:18] {2219} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 04-25 05:29:21] {2392} INFO -  at 24.2s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:21] {2219} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 04-25 05:29:24] {2392} INFO -  at 27.2s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:24] {2219} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 04-25 05:29:25] {2392} INFO -  at 27.5s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:25] {2219} INFO - iteration 25, current learner rf
# [flaml.automl.logger: 04-25 05:29:25] {2392} INFO -  at 27.9s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:25] {2219} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 04-25 05:29:25] {2392} INFO -  at 28.2s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:25] {2219} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 04-25 05:29:27] {2392} INFO -  at 30.0s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:27] {2219} INFO - iteration 28, current learner rf
# [flaml.automl.logger: 04-25 05:29:27] {2392} INFO -  at 30.3s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:27] {2219} INFO - iteration 29, current learner rf
# [flaml.automl.logger: 04-25 05:29:30] {2392} INFO -  at 32.6s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:29:30] {2219} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 04-25 05:29:40] {2392} INFO -  at 43.3s,	estimator rf's best error=0.0187,	best estimator rf's best error=0.0187
# [flaml.automl.logger: 04-25 05:30:49] {2628} INFO - retrain rf for 68.5s
# [flaml.automl.logger: 04-25 05:30:49] {2631} INFO - retrained model: RandomForestRegressor(max_features=0.6172053288755608, max_leaf_nodes=32767,
#                       n_estimators=567, n_jobs=-1, random_state=12032022)
# [flaml.automl.logger: 04-25 05:30:49] {1931} INFO - fit succeeded
# [flaml.automl.logger: 04-25 05:30:49] {1932} INFO - Time taken to find the best model: 43.287408113479614

# %%
print("best model:")
print(automl.model.estimator)
# Out:
# best model:
# RandomForestRegressor(max_features=0.6172053288755608, max_leaf_nodes=32767,
#                       n_estimators=567, n_jobs=-1, random_state=12032022)

# %%
y_pred_scaled = automl.predict(X_test_scaled)
test['predict_scaled'] = y_pred_scaled
y_pred_scaled = y_pred_scaled.reshape(-1, 1)
y_pred = min_max_scaler.inverse_transform(y_pred_scaled)
y_pred = y_pred.flatten()

test['predict'] = y_pred
test_mean = test.groupby('time').mean().reset_index()
test_mean = test_mean.drop(['source'], axis=1)

y_test_mean = test_mean['TREFMXAV_U_scaled']
y_test_pred = test_mean['predict_scaled']

mse = mean_squared_error(y_test_mean, y_test_pred)
mae = mean_absolute_error(y_test_mean, y_test_pred)
r2 = r2_score(y_test_mean, y_test_pred)
rmse = sqrt(mse)

print(f'Validation Mean Squared Error (MSE): {mse}')
print(f'Validation Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Validation R-squared: {r2}')
# Out:
# Validation Mean Squared Error (MSE): 4.9121847989880246e-05
# Validation Mean Absolute Error (MAE): 0.0054933591880941815
# Root Mean Squared Error (RMSE): 0.007008698023875779
# Validation R-squared: 0.9966554055320338
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\4132950310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict_scaled'] = y_pred_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\4132950310.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict'] = y_pred

# %% [markdown]
# Compare month and year

# %%
test_mean['year'] = test_mean['year'].astype(int)
test_mean['month'] = test_mean['month'].astype(int)
test_mean['dayofyear'] = test_mean['dayofyear'].astype(int)

monthly_mse = test_mean.groupby('month').apply(lambda x: mean_squared_error(x['TREFMXAV_U_scaled'], x['predict_scaled']))
monthly_mse = monthly_mse.reset_index().rename(columns={0: 'MSE'})

# %%
season_colors = {1: 'skyblue', 2: 'skyblue', 3: 'lightsalmon', 4: 'lightsalmon', 
                 5: 'lightsalmon', 6: 'mediumseagreen', 7: 'mediumseagreen', 
                 8: 'mediumseagreen', 9: 'khaki', 10: 'khaki', 11: 'khaki', 12: 'skyblue'}

# %%
plt.figure(figsize=(10, 6))
for index, row in monthly_mse.iterrows():
    plt.bar(row['month'], row['MSE'], color=season_colors[row['month']])
plt.xlabel('Month')
plt.ylabel('Mean Squared Error')
plt.title('Model Accuracy by Month(MSE)')
plt.xticks(monthly_mse['month'], labels=[f'{m}' for m in monthly_mse['month']])
plt.show()

# %%
monthly_r2 = test_mean.groupby('month').apply(lambda x: r2_score(x['TREFMXAV_U_scaled'], x['predict_scaled']))
monthly_r2 = monthly_r2.reset_index().rename(columns={0: 'R2'})

plt.figure(figsize=(10, 6))
#plt.bar(monthly_r2['month'], monthly_r2['R2'], color='skyblue')
for index, row in monthly_r2.iterrows():
    plt.bar(row['month'], row['R2'], color=season_colors[row['month']])
plt.xlabel('Month')
plt.ylabel('R^2 Score')
plt.title('Model Accuracy by Month(R2)')
plt.ylim(0.88, 1.0)
plt.show()

# %%
yearly_mse = test_mean.groupby('year').apply(lambda x: mean_squared_error(x['TREFMXAV_U_scaled'], x['predict_scaled']))
yearly_mse = yearly_mse.reset_index().rename(columns={0: 'MSE'})

plt.figure(figsize=(18, 6))
plt.bar(yearly_mse['year'], yearly_mse['MSE'], color='cornflowerblue')
plt.xlabel('Year')
plt.ylabel('Mean Squared Error')
plt.title('Model Accuracy by Year(MSE)')
plt.xticks(yearly_mse['year'], labels=[f'{m}' for m in yearly_mse['year']])
plt.show()

# %%
yearly_r2 = test_mean.groupby('year').apply(lambda x: r2_score(x['TREFMXAV_U_scaled'], x['predict_scaled']))
yearly_r2 = yearly_r2.reset_index().rename(columns={0: 'R2'})

plt.figure(figsize=(18, 6))
plt.bar(yearly_r2['year'], yearly_r2['R2'], color='cornflowerblue')
plt.xlabel('Year')
plt.ylabel('R^2 Score')
plt.title('Model Accuracy by Year(R2)')
plt.xticks(yearly_r2['year'], labels=[f'{m}' for m in yearly_r2['year']])
plt.ylim(0.99, 1.0)
plt.show()

# %% [markdown]
# compare different source

# %%
X_test_3 = test_3.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1)
X_test_4 = test_4.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 
X_test_5 = test_5.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 
X_test_6 = test_6.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 
X_test_7 = test_7.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 
X_test_8 = test_8.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1)

# %%
X_test_3_scaled = scaler.transform(X_test_3)
X_test_4_scaled = scaler.transform(X_test_4)
X_test_5_scaled = scaler.transform(X_test_5)
X_test_6_scaled = scaler.transform(X_test_6)
X_test_7_scaled = scaler.transform(X_test_7)
X_test_8_scaled = scaler.transform(X_test_8)

# %%
y_pred_3_scaled = automl.predict(X_test_3_scaled)
test_3['predict_scaled'] = y_pred_3_scaled
y_pred_3_scaled = y_pred_3_scaled.reshape(-1, 1)
y_pred_3 = min_max_scaler.inverse_transform(y_pred_3_scaled)
y_pred_3 = y_pred_3.flatten()
test_3['predict'] = y_pred_3

y_test_3 = test_3['TREFMXAV_U_scaled']
y_test_3_pred = test_3['predict_scaled']

mse_3 = mean_squared_error(y_test_3, y_test_3_pred)
r2_3 = r2_score(y_test_3, y_test_3_pred)

print(f'Validation Mean Squared Error (MSE): {mse_3}')
print(f'Validation R-squared: {r2_3}')
# Out:
# Validation Mean Squared Error (MSE): 0.00028347340095690766
# Validation R-squared: 0.9852920574141125
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\638571660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_3['predict_scaled'] = y_pred_3_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\638571660.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_3['predict'] = y_pred_3

# %%
y_pred_4_scaled = automl.predict(X_test_4_scaled)
test_4['predict_scaled'] = y_pred_4_scaled
y_pred_4_scaled = y_pred_4_scaled.reshape(-1, 1)
y_pred_4 = min_max_scaler.inverse_transform(y_pred_4_scaled)
y_pred_4 = y_pred_4.flatten()
test_4['predict'] = y_pred_4

y_test_4 = test_4['TREFMXAV_U_scaled']
y_test_4_pred = test_4['predict_scaled']

mse_4 = mean_squared_error(y_test_4, y_test_4_pred)
r2_4 = r2_score(y_test_4, y_test_4_pred)

print(f'Validation Mean Squared Error (MSE): {mse_4}')
print(f'Validation R-squared: {r2_4}')
# Out:
# Validation Mean Squared Error (MSE): 0.0002741250400232555
# Validation R-squared: 0.9846082672543552
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\2036651776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_4['predict_scaled'] = y_pred_4_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\2036651776.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_4['predict'] = y_pred_4

# %%
y_pred_5_scaled = automl.predict(X_test_5_scaled)
test_5['predict_scaled'] = y_pred_5_scaled
y_pred_5_scaled = y_pred_5_scaled.reshape(-1, 1)
y_pred_5 = min_max_scaler.inverse_transform(y_pred_5_scaled)
y_pred_5 = y_pred_5.flatten()
test_5['predict'] = y_pred_5

y_test_5 = test_5['TREFMXAV_U_scaled']
y_test_5_pred = test_5['predict_scaled']

mse_5 = mean_squared_error(y_test_5, y_test_5_pred)
r2_5 = r2_score(y_test_5, y_test_5_pred)

print(f'Validation Mean Squared Error (MSE): {mse_5}')
print(f'Validation R-squared: {r2_5}')
# Out:
# Validation Mean Squared Error (MSE): 0.0002763300371516043
# Validation R-squared: 0.9846575290364615
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\3289740144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_5['predict_scaled'] = y_pred_5_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\3289740144.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_5['predict'] = y_pred_5

# %%
y_pred_6_scaled = automl.predict(X_test_6_scaled)
test_6['predict_scaled'] = y_pred_6_scaled
y_pred_6_scaled = y_pred_6_scaled.reshape(-1, 1)
y_pred_6 = min_max_scaler.inverse_transform(y_pred_6_scaled)
y_pred_6 = y_pred_6.flatten()
test_6['predict'] = y_pred_6

y_test_6 = test_6['TREFMXAV_U_scaled']
y_test_6_pred = test_6['predict_scaled']

mse_6 = mean_squared_error(y_test_6, y_test_6_pred)
r2_6 = r2_score(y_test_6, y_test_6_pred)

print(f'Validation Mean Squared Error (MSE): {mse_6}')
print(f'Validation R-squared: {r2_6}')
# Out:
# Validation Mean Squared Error (MSE): 0.0002873632472304049
# Validation R-squared: 0.984141307729777
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\9744807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_6['predict_scaled'] = y_pred_6_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\9744807.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_6['predict'] = y_pred_6

# %%
y_pred_7_scaled = automl.predict(X_test_7_scaled)
test_7['predict_scaled'] = y_pred_7_scaled
y_pred_7_scaled = y_pred_7_scaled.reshape(-1, 1)
y_pred_7 = min_max_scaler.inverse_transform(y_pred_7_scaled)
y_pred_7 = y_pred_7.flatten()
test_7['predict'] = y_pred_7

y_test_7 = test_7['TREFMXAV_U_scaled']
y_test_7_pred = test_7['predict_scaled']

mse_7 = mean_squared_error(y_test_7, y_test_7_pred)
r2_7 = r2_score(y_test_7, y_test_7_pred)

print(f'Validation Mean Squared Error (MSE): {mse_7}')
print(f'Validation R-squared: {r2_7}')
# Out:
# Validation Mean Squared Error (MSE): 0.0002809475629659738
# Validation R-squared: 0.9849094014908379
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\827445152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_7['predict_scaled'] = y_pred_7_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\827445152.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_7['predict'] = y_pred_7

# %%
y_pred_8_scaled = automl.predict(X_test_8_scaled)
test_8['predict_scaled'] = y_pred_8_scaled
y_pred_8_scaled = y_pred_8_scaled.reshape(-1, 1)
y_pred_8 = min_max_scaler.inverse_transform(y_pred_8_scaled)
y_pred_8 = y_pred_8.flatten()
test_8['predict'] = y_pred_8

y_test_8 = test_8['TREFMXAV_U_scaled']
y_test_8_pred = test_8['predict_scaled']

mse_8 = mean_squared_error(y_test_8, y_test_8_pred)
r2_8 = r2_score(y_test_8, y_test_8_pred)

print(f'Validation Mean Squared Error (MSE): {mse_8}')
print(f'Validation R-squared: {r2_8}')
# Out:
# Validation Mean Squared Error (MSE): 0.00028792963297866756
# Validation R-squared: 0.9840986234858231
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\1549146448.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_8['predict_scaled'] = y_pred_8_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\1549146448.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_8['predict'] = y_pred_8

# %%
data_accuracy = {
    'Source':['source3','source4','source5','source6','source7','source8'],
    'MSE':[  mse_3, mse_4, mse_5, mse_6, mse_7, mse_8],
    'r2':[  r2_3, r2_4, r2_5, r2_6, r2_7, r2_8]
}
df_accuracy = pd.DataFrame(data_accuracy)

# %%
plt.figure(figsize=(8, 4))
plt.bar(df_accuracy['Source'], df_accuracy['MSE'], color='skyblue')
plt.xlabel('Data Source')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Model Prediction Accuracy by Data Source')
plt.ylim(0, max(df_accuracy['MSE']) + 0.00005)  
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(df_accuracy['Source'], df_accuracy['r2'], color='skyblue')
plt.xlabel('Data Source')
plt.ylabel('R2')
plt.title('Model Prediction Accuracy by Data Source')
plt.ylim(0.96, 1.0)
plt.show()

# %% [markdown]
# Location

# %%
lat = 50.418850
lon = 357.5
ds_sw = combined_dataset.sel(lat = lat, lon = lon, method = 'nearest')
#turn to dataframe
df_sw = ds_sw.to_dataframe().reset_index()
df_sw = df_sw.drop(['lat', 'lon'], axis=1)
#deal with time information
df_sw['time'] = df_sw['time'].astype(str)
df_sw['time'] = pd.to_datetime(df_sw['time'])
#Split time to year, month, day of year
df_sw['year'] = df_sw['time'].dt.year
df_sw['month'] = df_sw['time'].dt.month
df_sw['dayofyear'] = df_sw['time'].dt.dayofyear

#change source name
df_sw['source'] = df_sw['source'].str.split('_').str[0]
df_sw['source'] = df_sw['source'].astype(int)

df_sw['TREFMXAV_U_scaled'] = min_max_scaler.fit_transform(df_sw[['TREFMXAV_U']])

test_sw = df_sw[df_sw['time'].dt.year >= 2050]
X_sw_test = test_sw.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 

#scaler = StandardScaler()
X_sw_test_scaled = scaler.transform(X_sw_test)

y_sw_pred_scaled = automl.predict(X_sw_test_scaled)
test_sw['predict_scaled'] = y_sw_pred_scaled
y_sw_pred_scaled = y_sw_pred_scaled.reshape(-1, 1)
y_sw_pred = min_max_scaler.inverse_transform(y_sw_pred_scaled)
y_sw_pred = y_sw_pred.flatten()

test_sw['predict'] = y_sw_pred
test_sw_mean = test_sw.groupby('time').mean().reset_index()
test_sw_mean = test_sw_mean.drop(['source'], axis=1)

y_sw_test_mean = test_sw_mean['TREFMXAV_U']
y_sw_test_pred = test_sw_mean['predict']

r2_sw = r2_score(y_sw_test_mean, y_sw_test_pred)

print(f'AutoML R-squared: {r2_sw}')
# Out:
# AutoML R-squared: 0.8118556719111485
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\2220377447.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sw['predict_scaled'] = y_sw_pred_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\2220377447.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sw['predict'] = y_sw_pred

# %%
lat = 57.958115
lon = 356.25
ds_sw = combined_dataset.sel(lat = lat, lon = lon, method = 'nearest')
#turn to dataframe
df_sw = ds_sw.to_dataframe().reset_index()
df_sw = df_sw.drop(['lat', 'lon'], axis=1)
#deal with time information
df_sw['time'] = df_sw['time'].astype(str)
df_sw['time'] = pd.to_datetime(df_sw['time'])
#Split time to year, month, day of year
df_sw['year'] = df_sw['time'].dt.year
df_sw['month'] = df_sw['time'].dt.month
df_sw['dayofyear'] = df_sw['time'].dt.dayofyear

#change source name
df_sw['source'] = df_sw['source'].str.split('_').str[0]
df_sw['source'] = df_sw['source'].astype(int)

df_sw['TREFMXAV_U_scaled'] = min_max_scaler.fit_transform(df_sw[['TREFMXAV_U']])

test_sw = df_sw[df_sw['time'].dt.year >= 2050]
X_sw_test = test_sw.drop(['TREFMXAV_U', 'TREFMXAV_U_scaled','source','time'], axis=1) 

#scaler = StandardScaler()
X_sw_test_scaled = scaler.transform(X_sw_test)

y_sw_pred_scaled = automl.predict(X_sw_test_scaled)
test_sw['predict_scaled'] = y_sw_pred_scaled
y_sw_pred_scaled = y_sw_pred_scaled.reshape(-1, 1)
y_sw_pred = min_max_scaler.inverse_transform(y_sw_pred_scaled)
y_sw_pred = y_sw_pred.flatten()

test_sw['predict'] = y_sw_pred
test_sw_mean = test_sw.groupby('time').mean().reset_index()
test_sw_mean = test_sw_mean.drop(['source'], axis=1)

y_sw_test_mean = test_sw_mean['TREFMXAV_U']
y_sw_test_pred = test_sw_mean['predict']

r2_sw = r2_score(y_sw_test_mean, y_sw_test_pred)

print(f'AutoML R-squared: {r2_sw}')
# Out:
# AutoML R-squared: 0.8157015382538825
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\3513313708.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sw['predict_scaled'] = y_sw_pred_scaled
# C:\Users\HP\AppData\Local\Temp\ipykernel_12396\3513313708.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sw['predict'] = y_sw_pred

# %% [markdown]
# QBOT

# %%
qbot_min = test_mean['QBOT'].min()
qbot_max = test_mean['QBOT'].max()
qbot_bins = np.linspace(qbot_min, qbot_max, num=11)

# %%
test_mean['qbot_bin'] = pd.cut(test_mean['QBOT'], bins=qbot_bins, labels=np.arange(1, 11), include_lowest=True)

# %%
qbot_mse = test_mean.groupby('qbot_bin').apply(lambda x: mean_squared_error(x['TREFMXAV_U_scaled'], x['predict_scaled']))

# %%
plt.figure(figsize=(10, 6))
plt.bar(qbot_mse.index.astype(str), qbot_mse.values)
plt.xlabel('QBOT Bins')
plt.ylabel('Mean Squared Error')
plt.title('Model Accuracy Across QBOT Bins')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# project reflection:
#
# In this project, I used 6 sets of UK meteorological data to model and predict the Urban daily maximum of average 2-m temperature for Manchester from 2050 to 2080. During the model building process, I used AutoML to tune the hyperparameters of the model, resulting in an overall predicted Mean Squared Error (MSE) of 4.9121847989880246e-05 and an R-squared of 0.9966554055320338. In addition, I compared the accuracy of the model across months and years. Also compared the accuracy of the model with different data sources.
#
# However, the modelling is based on one city, Manchester, which leads to poor application of the model to the remaining cities. Subsequently, consideration needs to be given to incorporating coordinates into the model parameters to increase the breadth of model application.
